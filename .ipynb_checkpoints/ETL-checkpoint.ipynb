# %%
# Import dependencies
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
#Load in CSVs from http://nflsavant.com/about.php
data_2020 = "data/pbp-2020.csv"
yr2020_df = pd.read_csv(data_2020)

data_2019 = "data/pbp-2019.csv"
yr2019_df = pd.read_csv(data_2019)

data_2018 = "data/pbp-2018.csv"
yr2018_df = pd.read_csv(data_2018)

data_2017 = "data/pbp-2017.csv"
yr2017_df = pd.read_csv(data_2017)

data_2016 = "data/pbp-2016.csv"
yr2016_df = pd.read_csv(data_2016)

data_2015 = "data/pbp-2015.csv"
yr2015_df = pd.read_csv(data_2015)

data_2014 = "data/pbp-2014.csv"
yr2014_df = pd.read_csv(data_2014)

# %%
frames = [yr2020_df, yr2019_df, yr2018_df, yr2017_df, yr2016_df, yr2015_df, yr2014_df]
nfl_data = pd.concat(frames)
#nfl_data

# %%
nan_value = float("NaN")
nfl_data.replace("", nan_value, inplace=True)
nfl_data.dropna(subset = ["OffenseTeam"], inplace=True)
#nfl_data

# %%
nfl_data = nfl_data.drop(columns = "Challenger")
#nfl_data

# %%
nfl_data.dropna(how='all', axis=1, inplace=True)

# %%
nfl_data
# Out:
#            GameId    GameDate  Quarter  Minute  Second OffenseTeam  \
# 0      2020122602  2020-12-26        2       9      44          LV
# 1      2020122602  2020-12-26        2       9       3          LV
# 2      2020122500  2020-12-25        3       1      17         MIN
# 3      2020122500  2020-12-25        3       1      12         MIN
# 4      2020122500  2020-12-25        3       1       6         MIN
# ...           ...         ...      ...     ...     ...         ...
# 45690  2014122815  2014-12-28        3      11      21         SEA
# 45691  2014122815  2014-12-28        3      11      17         SEA
# 45692  2014122815  2014-12-28        3      11      13         SEA
# 45693  2014122815  2014-12-28        3       9      12         SEA
# 45694  2014122815  2014-12-28        4       0      40         SEA
#
#       DefenseTeam  Down  ToGo  YardLine  ...  IsTwoPointConversion  \
# 0             MIA     2    10        82  ...                     0
# 1             MIA     3    19        73  ...                     0
# 2              NO     3     9        67  ...                     0
# 3              NO     1    10        82  ...                     0
# 4              NO     1     1        99  ...                     0
# ...           ...   ...   ...       ...  ...                   ...
# 45690          LA     3     8        76  ...                     0
# 45691          LA     4     8        76  ...                     0
# 45692          LA     0     0        35  ...                     0
# 45693          LA     1    10        31  ...                     0
# 45694          LA     3    13        64  ...                     0
#
#        IsTwoPointConversionSuccessful RushDirection  YardLineFixed  \
# 0                                   0           NaN             18
# 1                                   0    LEFT GUARD             27
# 2                                   0           NaN             33
# 3                                   0           NaN             18
# 4                                   0    LEFT GUARD              1
# ...                               ...           ...            ...
# 45690                               0           NaN             24
# 45691                               0           NaN             24
# 45692                               0           NaN             35
# 45693                               0    LEFT GUARD             31
# 45694                               0           NaN             36
#
#        YardLineDirection  IsPenaltyAccepted PenaltyTeam IsNoPlay  \
# 0                    OPP                  0         NaN        0
# 1                    OPP                  0         NaN        0
# 2                    OPP                  0          NO        1
# 3                    OPP                  1          NO        1
# 4                    OPP                  0         NaN        0
# ...                  ...                ...         ...      ...
# 45690                OPP                  0         NaN        0
# 45691                OPP                  0         NaN        0
# 45692                OWN                  0         NaN        0
# 45693                OWN                  0         NaN        0
# 45694                OPP                  0         NaN        0
#
#                        PenaltyType  PenaltyYards
# 0                              NaN             0
# 1                              NaN             0
# 2                DEFENSIVE HOLDING             0
# 3      DEFENSIVE PASS INTERFERENCE            17
# 4                              NaN             0
# ...                            ...           ...
# 45690                          NaN             0
# 45691                          NaN             0
# 45692                          NaN             0
# 45693                          NaN             0
# 45694                          NaN             0
#
# [292914 rows x 40 columns]

# %%
# nfl_data.to_csv("nfldata.csv")

# %%
nfl_data.dtypes
# Out:
# GameId                             int64
# GameDate                          object
# Quarter                            int64
# Minute                             int64
# Second                             int64
# OffenseTeam                       object
# DefenseTeam                       object
# Down                               int64
# ToGo                               int64
# YardLine                           int64
# SeriesFirstDown                    int64
# NextScore                          int64
# Description                       object
# TeamWin                            int64
# SeasonYear                         int64
# Yards                              int64
# Formation                         object
# PlayType                          object
# IsRush                             int64
# IsPass                             int64
# IsIncomplete                       int64
# IsTouchdown                        int64
# PassType                          object
# IsSack                             int64
# IsChallenge                        int64
# IsChallengeReversed                int64
# IsMeasurement                      int64
# IsInterception                     int64
# IsFumble                           int64
# IsPenalty                          int64
# IsTwoPointConversion               int64
# IsTwoPointConversionSuccessful     int64
# RushDirection                     object
# YardLineFixed                      int64
# YardLineDirection                 object
# IsPenaltyAccepted                  int64
# PenaltyTeam                       object
# IsNoPlay                           int64
# PenaltyType                       object
# PenaltyYards                       int64
# dtype: object

# %%
#clean 2019
nan_value = float("NaN")
yr2019_df.replace("", nan_value, inplace=True)
yr2019_df.dropna(subset = ["OffenseTeam"], inplace=True)
clean_2019 = yr2019_df[["Quarter","OffenseTeam","PlayType","IsRush","IsPass"]]
clean_2019.dropna(how='all', axis=1, inplace=True)
clean_2019
# Out:
# <ipython-input-24-85aaa9ba3ea7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_2019.dropna(how='all', axis=1, inplace=True)
#        Quarter OffenseTeam  PlayType  IsRush  IsPass
# 0            4         LAC      PASS       0       1
# 1            4         LAC      PASS       0       1
# 2            4         LAC      PASS       0       1
# 3            4         LAC      PASS       0       1
# 4            4         LAC      PASS       0       1
# ...        ...         ...       ...     ...     ...
# 42167        2         HOU      RUSH       1       0
# 42175        1         ARI      PUNT       0       0
# 42182        3         BAL  KICK OFF       0       0
# 42184        3          GB  KICK OFF       0       0
# 42185        2          GB  KICK OFF       0       0
#
# [39078 rows x 5 columns]

# %%
#groupby quarter and team
grouped = clean_2019.groupby(['Quarter',"OffenseTeam"])
grouped_2019 = grouped.sum()
grouped_2019
# Out:
#                      IsRush  IsPass
# Quarter OffenseTeam
# 1       ARI              95     119
#         ATL             108     141
#         BAL             110      99
#         BUF             100     119
#         CAR             102     117
# ...                     ...     ...
# 5       PIT               1       1
#         SEA               7      20
#         SF                3       5
#         TB                0       0
#         WAS               0       0
#
# [142 rows x 2 columns]

# %%
#import nfl scores csv
scores = "data/NFL_Scores.csv"
score_df = pd.read_csv(scores)
# score_df

# %%
new_scores = score_df.rename(columns={"Losser":"Loser"})
new_scores
# Out:
#      Score  PtsW  PtsL  PtTot  PtDif                 Winner  \
# 0     31-9    31     9     40     22   Tampa Bay Buccaneers
# 1    31-26    31    26     57      5   Tampa Bay Buccaneers
# 2    38-24    38    24     62     14     Kansas City Chiefs
# 3    22-17    22    17     39      5     Kansas City Chiefs
# 4    30-20    30    20     50     10   Tampa Bay Buccaneers
# ..     ...   ...   ...    ...    ...                    ...
# 677  37-25    37    25     62     12        Detroit Lions
# 678  59-14    59    14     73     45      Oakland Raiders
# 679   15-9    15     9     24      6  Pittsburgh Steelers
# 680  51-45    51    45     96      6    Arizona Cardinals
# 681  44-24    44    24     68     20     Kansas City Chiefs
#
#                    Loser        Date
# 0     Kansas City Chiefs    2/7/2021
# 1      Green Bay Packers   1/24/2021
# 2          Buffalo Bills   1/24/2021
# 3       Cleveland Browns   1/17/2021
# 4     New Orleans Saints   1/17/2021
# ..                   ...         ...
# 677  Washington Redskins  10/31/2010
# 678       Denver Broncos  10/24/2010
# 679      Atlanta Falcons   9/12/2010
# 680    Green Bay Packers   1/10/2010
# 681       Denver Broncos    1/3/2010
#
# [682 rows x 8 columns]

# %%
# new_scores.dtypes

# %%
play_data = "data/NFL_Play_Data_Final.csv"
nfl_plays = pd.read_csv(play_data)
nfl_plays
# Out:
#             GameId    GameDate  Quarter  Minute  Second OffenseTeam  \
# 0       2014090400  2014-09-04        1       0      20         SEA
# 1       2014090400  2014-09-04        1       0      59         SEA
# 2       2014090400  2014-09-04        1       1      25          GB
# 3       2014090400  2014-09-04        1       1      25          GB
# 4       2014090400  2014-09-04        1       1      25         SEA
# ...            ...         ...      ...     ...     ...         ...
# 292909  2021010315  2021-01-03        4      14      22          SF
# 292910  2021010315  2021-01-03        4      14      22          SF
# 292911  2021010315  2021-01-03        4      14      22         SEA
# 292912  2021010315  2021-01-03        4      14      26          SF
# 292913  2021010315  2021-01-03        4      15       0          SF
#
#        DefenseTeam Team1 Team2  Down  ...  FinalScoreSpread_Team1  \
# 0               GB   SEA    GB     2  ...                       0
# 1               GB   SEA    GB     1  ...                       0
# 2              SEA   SEA    GB     0  ...                       0
# 3              SEA   SEA    GB     0  ...                       0
# 4               GB   SEA    GB     1  ...                       0
# ...            ...   ...   ...   ...  ...                     ...
# 292909         SEA   SEA    SF     0  ...                       0
# 292910         SEA   SEA    SF     0  ...                       0
# 292911          SF   SEA    SF     1  ...                       0
# 292912         SEA   SEA    SF     2  ...                       0
# 292913         SEA   SEA    SF     1  ...                       3
#
#         FinalScoreSpread_Team2  FinalScoreLabel_Team1 FinalScoreLabel_Team2  \
# 0                            0                   Tied                  Tied
# 1                            0                   Tied                  Tied
# 2                            0                   Tied                  Tied
# 3                            0                   Tied                  Tied
# 4                            0                   Tied                  Tied
# ...                        ...                    ...                   ...
# 292909                       0                   Tied                  Tied
# 292910                       0                   Tied                  Tied
# 292911                       0                   Tied                  Tied
# 292912                       0                   Tied                  Tied
# 292913                      -3           Won by 3 Pts         Lost by 3 Pts
#
#         OvertimeScore_Team1 OvertimeScore_Team2 OvertimeScoreSpread_Team1  \
# 0                         0                   0                         0
# 1                         0                   0                         0
# 2                         0                   0                         0
# 3                         0                   0                         0
# 4                         0                   0                         0
# ...                     ...                 ...                       ...
# 292909                    0                   0                         0
# 292910                    0                   0                         0
# 292911                    0                   0                         0
# 292912                    0                   0                         0
# 292913                    0                   0                         0
#
#         OvertimeScoreSpread_Team2 OvertimeScoreLabel1  OvertimeScoreLabel2
# 0                               0                Tied                 Tied
# 1                               0                Tied                 Tied
# 2                               0                Tied                 Tied
# 3                               0                Tied                 Tied
# 4                               0                Tied                 Tied
# ...                           ...                 ...                  ...
# 292909                          0                Tied                 Tied
# 292910                          0                Tied                 Tied
# 292911                          0                Tied                 Tied
# 292912                          0                Tied                 Tied
# 292913                          0                Tied                 Tied
#
# [292914 rows x 53 columns]

# %%
nfl_plays.dtypes
# Out:
# GameId                        int64
# GameDate                     object
# Quarter                       int64
# Minute                        int64
# Second                        int64
# OffenseTeam                  object
# DefenseTeam                  object
# Team1                        object
# Team2                        object
# Down                          int64
# ToGo                          int64
# YardLine                      int64
# YardLineFixed                 int64
# FieldPosition                object
# Yards                         int64
# Formation                    object
# PlayType                     object
# IsRush                        int64
# RushDirection                object
# IsPass                        int64
# PassType                     object
# IsIncomplete                  int64
# FieldGoalRange                int64
# IsTouchdown                   int64
# IsFieldGoal                   int64
# Description                  object
# IsPenalty                     int64
# PenaltyTeam                  object
# PenaltyYards                  int64
# TDPoints                      int64
# ExtraPoints                   int64
# FGPoints                      int64
# SafetyPoints                  int64
# PointsOnPlay_Team1            int64
# PointsOnPlay_Team2            int64
# CurrentScore_Team1            int64
# CurrentScore_Team2            int64
# CurrentSpread_Team1           int64
# CurrentSpread_Team2           int64
# CurrentScorePostion_Team1    object
# CurrentScorePostion_Team2    object
# FinalScore_Team1              int64
# FinalScore_Team2              int64
# FinalScoreSpread_Team1        int64
# FinalScoreSpread_Team2        int64
# FinalScoreLabel_Team1        object
# FinalScoreLabel_Team2        object
# OvertimeScore_Team1           int64
# OvertimeScore_Team2           int64
# OvertimeScoreSpread_Team1     int64
# OvertimeScoreSpread_Team2     int64
# OvertimeScoreLabel1          object
# OvertimeScoreLabel2          object
# dtype: object

# %%
engine = create_engine("sqlite:///nfldata.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
print(Base.classes.keys())
#Save reference to the tables
nfl = Base.classes.nfl
scores = Base.classes.scores
plays = Base.classes.plays
# Out:
# ['nfl', 'plays', 'scores']

# %%
#nfl_data.to_sql(name='nfl', con=engine, if_exists='append', index=False)

# %%
# new_scores.to_sql(name="scores", con=engine, if_exists='append', index=False)

# %%
# clean_2019.to_sql(name="plays", con=engine, if_exists="append", index=False)
